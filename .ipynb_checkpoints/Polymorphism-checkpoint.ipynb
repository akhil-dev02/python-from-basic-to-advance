# %%
# Types of polymorphism
#1. Method overriding (run time polymorphism)
class person:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    def details(self):
        return f"My name is {self.name} and iam a {self.age} year old"
class student(person):
    def __init__(self,name,age,rollnum):
        super().__init__(name,age)
        self.rollnum = rollnum
    def details(self):
        return f"iam astudent"
p = person("ravi", 15)
c = student("Akhil",20,101)
print(c.details())
print(p.details())
# Out:
# iam astudent
# My name is ravi and iam a 15 year old

# %%
class person:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    def details(self):
        return f"My name is {self.name} and iam a {self.age} year old"
class student(person):
    def __init__(self,name,age,rollnum):
        super().__init__(name,age)
        self.rollnum = rollnum
    def details(self):
        return super().details() + f"iam astudent"
p = person("ravi", 15)
c = student("Akhil",20,101)
print(c.details())
print(p.details())
print(c.name,c.age,c.rollnum)
# Out:
# My name is Akhil and iam a 20 year oldiam astudent
# My name is ravi and iam a 15 year old
# Akhil 20 101

# %%
# Method overloading (compile time polymorphism)
class math:
    def add(a,b,c=0,d=0):
        return f"{a+b+c+d}"
print(math.add(1,2,3,4))
print(math.add(1,2,3))
print(math.add(1,2))
# Out:
# 10
# 6
# 3

# %%
# operator Overloading
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y
p1 = Point(1,2)
print(p1)
# Out:
# <__main__.Point object at 0x000001D4BE0A3B60>

# %%
# operator Overloading
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y
    def __str__(self): # string magic method
        return f" This point class and value is:({self.x}, {self.y})"
p1 = Point(5,3)
print(p1)
# Out:
#  This point class and value is:(5, 3)

# %%
# operator Overloading
class Point:
    def __init__(self,x):
        self.x = x
    def __str__(self): # string magic method
        return f" This point class and value is:{self.x}"
p1 = Point(5)
print(p1)
# Out:
#  This point class and value is:5

# %%
# operator Overloading
class Point:
    def __init__(self,x):
        self.x = x
    def __str__(self): # string magic method
        return f" This point class and value is:{self.x}"
p1 = Point(5)
p2 = Point(3)
print(p1.x + p2.x)
# Out:
# 8

# %%
# operator Overloading
class Point:
    def __init__(self,x):
        self.x = x
    def __str__(self): # string magic method
        return f" This point class and value is:{self.x}"
    def __add__(self, other):
        return self.x + other.x
p1 = Point(5)
p2 = Point(3)
print(p1 + p2)
print(p1.x + p2.x)
# Out:
# 8
# 8

# %%
# operator Overloading
class Point:
    def __init__(self,x):
        self.x = x
    def __str__(self): # string magic method
        return f" This point class and value is:{self.x}"
    def __add__(self, other):
        return self.x + other.x
    def __sub__(self,other):
        return self.x - other.x
p1 = Point(5)
p2 = Point(3)
print(p1 + p2)
print(p1.x + p2.x)
print(p1.x - p2.x)
# Out:
# 8
# 8
# 2

# %%
# operator Overloading
class Point:
    def __init__(self,x):
        self.x = x
    def __str__(self): # string magic method
        return f" This point class and value is:{self.x}"
    def __add__(self, other):
        return str(self.x) + str(other.x)
p1 = Point(5)
p2 = Point(3)
print(p1 + p2)
print(p1.x + p2.x)
# Out:
# 53
# 8

# %%
# Overloading 
class point:
    def __init__(self, x):
        self.x = x

    def __str__(self):
        return str(self.x)

    # Arithmetic Operators
    def __add__(self, other):
        return point(self.x + other.x)

    def __sub__(self, other):
        return point(self.x - other.x)

    def __mul__(self, other):
        return point(self.x * other.x)

    def __truediv__(self, other):
        return point(self.x / other.x)

    def __floordiv__(self, other):
        return point(self.x // other.x)

    def __mod__(self, other):
        return point(self.x % other.x)

    def __pow__(self, other):
        return point(self.x ** other.x)

    # Unary Operators
    def __neg__(self):
        return point(-self.x)

    def __pos__(self):
        return point(+self.x)

    def __abs__(self):
        return abs(self.x)

    # Relational Operators
    def __eq__(self, other):
        return self.x == other.x

    def __ne__(self, other):
        return self.x != other.x

    def __lt__(self, other):
        return self.x < other.x

    def __le__(self, other):
        return self.x <= other.x

    def __gt__(self, other):
        return self.x > other.x

    def __ge__(self, other):
        return self.x >= other.x


p1 = point(10)
p2 = point(3)

print("Addition:", p1 + p2)
print("Subtraction:", p1 - p2)
print("Multiplication:", p1 * p2)
print("Division:", p1 / p2)
print("Floor Division:", p1 // p2)
print("Modulus:", p1 % p2)
print("Power:", p1 ** p2)

print("Negative:", -p1)
print("Positive:", +p1)
print("Absolute:", abs(point(-10)))

print("Equal:", p1 == p2)
print("Not Equal:", p1 != p2)
print("Less Than:", p1 < p2)
print("Less Than or Equal:", p1 <= p2)
print("Greater Than:", p1 > p2)
print("Greater Than or Equal:", p1 >= p2)
# Out:
# Addition: 13
# Subtraction: 7
# Multiplication: 30
# Division: 3.3333333333333335
# Floor Division: 3
# Modulus: 1
# Power: 1000
# Negative: -10
# Positive: 10
# Absolute: 10
# Equal: False
# Not Equal: True
# Less Than: False
# Less Than or Equal: False
# Greater Than: True
# Greater Than or Equal: True
