# %% [markdown]
# - Types of inheritance

# %%
# 1. Single Inheritance
# With implementation in child class
# when child class don't have constructor, In this case parent class constructor behaves like child class constructor
# parent class
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    def details(self):
        return f"My name is {self.name} and I am a {self.age} years old"
# child class
class Student(Person):
    pass

s = Student("ravi",20)
print(s.name)
print(s.details())
# Out:
# ravi
# My name is ravi and I am a 20 years old

# %%
class Person:
    def __init__(self,name,age,gender):
        self.name = name
        self.age = age
        self.gender = gender
    def details(self):
        return f"My name is {self.name} and I am a {self.age} years old"
# child class
class Student(Person):
    def __init__(self,stdid,name,age):
        self.stdid = stdid
        self.name = name
        self.age = age

s = Student(101,"ravi",20)
print(s.name)
print(s.details())
# Out:
# ravi
# My name is ravi and I am a 20 years old

# %%
class Person:
    def __init__(self,name,age,gender):
        self.name = name
        self.age = age
        self.gender = gender
    def details(self):
        return f"My name is {self.name} and I am a {self.age} years old and {self.gender}"
# child class
class Student(Person):
    def __init__(self,stdid,name,age):
        self.stdid = stdid
        self.name = name
        self.age = age

s = Student(101,"ravi",20)
print(s.name)
s.gender = "Male" # adding new instance attribute
print(s.details())
# Out:
# ravi
# My name is ravi and I am a 20 years old and Male

# %%
# Inherete the parent class constructor in child class by using super()
# super(): This function is user
# Parent class
class Person:
    def __init__(self,name,age,gender):
        self.name = name
        self.age = age
        self.gender = gender
    def details(self):
        return f"My name is {self.name} and I am a {self.age} years old and {self.gender}"
# child class
class Student(Person):
    def __init__(self,stdid,name,age,gender):
        self.stdid = stdid
        super().__init__(name,age,gender)
    def percentage(self,marks:list):
        return sum(marks)/len(marks)

s = Student(101,"ravi",20,"male")
print(s.name)
print(s.percentage([90,89,88]))
print(s.details())
# Out:
# ravi
# 89.0
# My name is ravi and I am a 20 years old and male

# %%
# Multilevel Inheritance
class employee:
    company = "Akhil private limited"
    def __init__(self,id,name,salary):
        self.id = id
        self.name = name
        self.salary = salary
    def calculate_salary(self,bonous=0):
        return self.salary + bonous
    
class teamlead(employee):
    def __init__(self,id,name,salary,project_name):
        self.project_name = project_name
        super().__init__(id,name,salary)
    def project_status(self,status):
        return f"{self.project_name} project status: {status}% completed"
class manager(teamlead):
    def __init__(self,id,name,salary,project,no_projects):
        self.no_projects = no_projects
        super().__init__(id,name,salary,project)
e = employee(101,"Akhil",30000)
t = teamlead(102,"karthik",40000,"practice tracking project")
m = manager(103,"kishorereddy",50000,"Exam portal project",5)
print(e.name,t.name,m.name)
print(e.calculate_salary())
print(t.calculate_salary(5000))
print(t.project_status(90))
print(m.calculate_salary(10000))
print(m.project_status(80))
# Out:
# Akhil karthik kishorereddy
# 30000
# 45000
# practice tracking project project status: 90% completed
# 60000
# Exam portal project project status: 80% completed

# %%
# Multiple Inheritance
class Father:
    def __init__(self,father_name):
        self.father_name=father_name
    def working1(self):
        return f" Father working as engineer"
class Mother:
    def __init__(self,mother_name):
        self.mother_name=mother_name
    def working2(self):
            return f" mother working as Houswife"
class child(Father,Mother):
    def __init__(self, name,father_name,mother_name):
        self.name=name
        Mother.__init__(self,mother_name)
        Father.__init__(self,father_name)
    def working(self):
         print(super().working1())
         print(super().working2())
c=child("Akhil","Aruna","vijender")
print(c.father_name)
print(c.mother_name)
print(child.__mro__)#Method resolution order
print(c.working())
# Out:
# Aruna
# vijender
# (<class '__main__.child'>, <class '__main__.Father'>, <class '__main__.Mother'>, <class 'object'>)
#  Father working as engineer
#  mother working as Houswife
# None
