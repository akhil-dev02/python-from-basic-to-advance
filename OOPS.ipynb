# %%
# create mobile class
class Mobile:
    company = "Iphone"
    def __init__(self, model ,ram, rom, price):
        self.model = model
        self.ram = ram
        self.rom = rom
        self.price = price
# object creation
iphone17 = Mobile("iphone 17", 8,256, 83000)
iphone16 = Mobile("iphone 16", 12,256, 120000)
print(iphone16.price)
print(iphone17.price)
print(iphone16.company)
print(iphone17.company)
print(Mobile.company)
# Out:
# 120000
# 83000
# Iphone
# Iphone
# Iphone

# %%
# Updating Instance attribute data from out side class
class Mobile:
    company = "Iphone"
    def __init__(self, model,price, ram =8, rom =256):
        self.model = model
        self.ram = ram
        self.rom = rom
        self.price = price
# object creation
iphone17 = Mobile("iphone 17", 83000)
iphone16 = Mobile("iphone 16", 120000,16)
print(iphone16.ram)
iphone16.ram =16
iphone16.company ="New Iphone"
print(iphone16.company, iphone17.company)
# Out:
# 16
# New Iphone Iphone

# %%
# create mobile class
class Mobile:
    company = "Iphone"
    def __init__(self, model ,ram, rom, price):
        self.model = model
        self.ram = ram
        self.rom = rom
        self.price = price
    def about_phone(self):
        return f"The {self.model} have {self.ram} GB RAM and {self.rom}GB ROM"
    def update_company(cls, new_name):
    cls.company = new_new
    return "Company name updated"
# static method
@staticmetod
  def charger_provide(cable = True):
    return "adapter + cable" if cable else "only adapter"
# object creation
iphone17 = Mobile("iphone 17", 8,256, 83000)
iphone16 = Mobile("iphone 16", 12,256, 120000)
print(iphone16.price)
print(iphone17.price)
print(iphone16.company)
print(iphone17.company)
print(Mobile.company)
print(iphone16.about_phone())
# calss method
@classmethod
def update_company(cls, new_name):
    cls.company = new_new
    return "Company name updated"
# static method
@staticmetod
def charger_provide(cable = True):
    return "adapter + cable" if cable else "only adapter"
# Out:
# 120000
# 83000
# Iphone
# Iphone
# Iphone
# The iphone 16 have 12 GB RAM and 256GB ROM

# %%
# create mobile class
class Mobile:
    company="Iphone"
    def __init__(self,model,ram,rom,price):
        self.model = model
        self.ram = ram
        self.rom = rom
        self.price = price
    def about_phone(self):
        return f"The {self.model} have  {self.ram} GB RAM and {self.rom}GB ROM"
    def display():
        return "This is samsung company display"
    # class method
    @classmethod
    def updated_company(cls, new_name):
        cls.company = new_name
        return "company name updated"
    # static method
    @staticmethod
    def charger_provide(cable = True):
        return "adapter + cable" if cable else "only adapter"
# object creation
iphone16 = Mobile("iphone 16", 16,256,125000)
iphone17 = Mobile("iphone 17", 8,256,120000) 
print(iphone16.about_phone())
print(iphone16.updated_company("Iphone pro"))
print(iphone16.charger_provide())
print(iphone17.company)
# Out:
# The iphone 16 have  16 GB RAM and 256GB ROM
# company name updated
# adapter + cable
# Iphone pro

# %%
# create mobile class
class Mobile:
    company="Iphone"
    def __init__(self,model,ram,rom,price):
        self.model = model
        self.ram = ram
        self.rom = rom
        self.price = price
    def about_phone(self):
        return f"The {self.model} have  {self.ram} GB RAM and {self.rom}GB ROM"
    def display():
        return "This is samsung company display"
    # class method
    @classmethod
    def updated_company(cls, new_name):
        cls.company = new_name
        return "company name updated"
    # static method
    @staticmethod
    def charger_provide(cable = True):
        return "adapter + cable" if cable else "only adapter"
# object creation
iphone16 = Mobile("iphone 16", 16,256,125000)
iphone17 = Mobile("iphone 17", 8,256,120000) 
print(Mobile.updated_company("Iphone pro"))
print(Mobile.charger_provide())
print(Mobile.company)
# Out:
# company name updated
# adapter + cable
# Iphone pro

# %%
class Accounts:
    def __init__(self,username,balance,password):
        self.username = username
        self.balance = balance
        self.password = password
    def withdraw(self,amount):
        if self.balance >= amount:
            self.balance -= amount
            return f"{amount} withdrawal successfully"
        return "Insufficient Balance"
    def deposite(self,amount):
        self.balance += amount
        return f"{amount} Deposite successfully and current Balance is {self.balance}"
user = Accounts("Akhil", 5000, "srinu@123")


print(user.deposite(1000))
user.balance = 100000
print(user.withdraw(50000))
# Out:
# 1000 Deposite successfully and current Balance is 6000
# 50000 withdrawal successfully

# %%
class Account:
    def __init__(self,name,balance,password,):
        self.name = name # public
        self._balance = balance # protective
        self.__password = password # private
    def get_balance(self):
        return self._balance
    def update_password(self,new_password): # setter method
        self.__password = new_password
        return "Password updated"
    def get_password(self):  #getter method
        return self.__password
    
    def withdraw(self,amount): # setter method
        if self._balance >= amount:
           self._balance <= amount
           return f"{amount} withdrawl successfully"
        return "Insufficient Balance"
    def deposite(self,amount): # setter method
        self._balance += amount
        return f"{amount} Deposite successfully and current Balance is {self._balance}"
    def __total_users(self):
        return "total users: 100"
user = Account("Akhil", 5000 , "kishore@123")
print(user.name)
print(user.get_balance())
print(user.deposite(5000))
print(user.update_password("Akhil@123"))
print(user.get_password())

# access the protected member syntax: obj._attributename
print(user._balance)
# access private member by using name mangling
# syntax : obj._classname__attributename
print(user._Account__total_users())
# Out:
# Akhil
# 5000
# 5000 Deposite successfully and current Balance is 10000
# Password updated
# Akhil@123
# 10000
# total users: 100
