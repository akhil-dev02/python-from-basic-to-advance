# %%
units = int(input())
citizen = input()
if units<=100:
    bill = units * 1.5
elif units<=200:
    bill = units * 2.5
elif units<=500:
    bill = units * 4
else:
    bill = units * 6 
if citizen == "yes":
    bill = bill - (bill *0.10)
if units > 500:
    bill = bill + (bill * 0.05)
print(bill)
# Out:
#  500
#  not citizen
# 2000
